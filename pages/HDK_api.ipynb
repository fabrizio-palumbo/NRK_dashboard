# %%
########### Python 3.2 #############
import urllib.request, json

try:
    url = "https://api-qa.helsedirektoratet.no/innhold/intern-import/kvalitetsindikatorer"

    hdr ={
    # Request headers
    'Cache-Control': 'no-cache',
    'Ocp-Apim-Subscription-Key': 'fcfaf33c95924f5ba8489370728a35bc',
    }

    req = urllib.request.Request(url, headers=hdr)

    req.get_method = lambda: 'GET'
    response = urllib.request.urlopen(req)
    print(response.getcode())
    a=response.read()
except Exception as e:
    exception=e
    print(e)
####################################
# Out:
# 200

# %%
import webbrowser
f = open('GFG.html', 'w')
f.write(str(a))
f.close()
import os
filename = 'file:///'+os.getcwd()+'/' + 'GFG.html'
webbrowser.open_new_tab(filename)
# Out:
# True

# %%
########### Python 3.2 #############
import urllib.request, json

try:
    url = "https://api-qa.helsedirektoratet.no/innhold/intern-import/retningslinjer"

    hdr ={
    # Request headers
    'Cache-Control': 'no-cache',
    'Ocp-Apim-Subscription-Key': 'fcfaf33c95924f5ba8489370728a35bc',
    }

    req = urllib.request.Request(url, headers=hdr)

    req.get_method = lambda: 'GET'
    response = urllib.request.urlopen(req)
    print(response.getcode())
    print(response.read())
except Exception as e:
    print(e)
####################################
# Out:
# HTTP Error 404: Not Found

# %%
########### Python 3.2 #############
import urllib.request, json

try:
    url = "https://api-qa.helsedirektoratet.no/innhold/intern-import/kvalitetsindikatorer/fabrizio/data?contentType=text%2Fcsv"

    hdr ={
    # Request headers
    'Cache-Control': 'no-cache',
    'Ocp-Apim-Subscription-Key': 'fcfaf33c95924f5ba8489370728a35bc',
    }

    req = urllib.request.Request(url, headers=hdr)

    req.get_method = lambda: 'GET'
    response = urllib.request.urlopen(req)
    print(response.getcode())
    print(response.read())
except Exception as e:
    print(e)
####################################
# Out:
# 204
# b''

# %%
a
# Out:
# b'<!DOCTYPE html><html lang="nb"><head><title>HAPI</title><link href="https://helsedirektoratet-cdn.azureedge.net/profilering/css/helfo.css" rel="stylesheet" /></head><body>\r\n<article class="col-md-8 col-xs-12 col-md-offset-2 t-body-text">\r\n<div class="row">\r\n<h1>Pakkeforl\xf8p for 24 organspesifikke kreftformer </h1>\r\n</div>\r\n<div class="row">\r\n<div class="b-list-item-type__text"><strong>Id: </strong>0003-0010-3</div>\r\n</div>\r\n<div class="row">\r\n<div></div>\r\n</div>\r\n<div class="row">\r\n<div class="b-list-item-type">\r\n<div class="b-list-item-type__meta"><strong>InfoId: </strong>3</div>\r\n<div class="b-list-item-type__meta"><strong>InfoType: </strong>kvalitetsindikator</div>\r\n<div class="b-list-item-type__meta"><strong>Subtype: </strong></div>\r\n</div>\r\n</div>\r\n<div class="row">\r\n<div class="b-list-item-type">\r\n<div class="b-list-item-type__meta"><strong>Sektor: </strong>Spesialisthelsetjenesten</div>\r\n<div class="b-list-item-type__meta"><strong>
# ...

# %%
########### Python 3.2 #############
import urllib.request, json

try:
    url = "https://api-qa.helsedirektoratet.no/innhold/intern-import/kvalitetsindikatorer"

    hdr ={
    # Request headers
    'Cache-Control': 'no-cache',
    'Ocp-Apim-Subscription-Key': 'fcfaf33c95924f5ba8489370728a35bc',
    }

    req = urllib.request.Request(url, headers=hdr)

    req.get_method = lambda: 'GET'
    response = urllib.request.urlopen(req)
    print(response.getcode())
    print(response.read())
except Exception as e:
    print(e)
####################################
# Out:
# 200
# ...
